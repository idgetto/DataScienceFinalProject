# %%
import pandas as pd

data = pd.read_csv('../data/olin0216.csv')
data.head()
# Out:
#    studentid  semester grade                     major  \
# 0   30876146  0708FA      SR  Engineering
# 1   23925034  0607FA      SR  Engineering
# 2   99052948  0607FA      SR  Electr'l & Computer Engr
# 3   29826367  0607FA      SR  Mechanical Engineering
# 4   91614816  0607FA      SR  Mechanical Engineering
#
#               concentration          code section  \
# 0  Computing                 AHS CAP SPR        1
# 1  Bioengineering            AHS CAP SPR        1
# 2                       NaN  AHS CAP SPR        1
# 3                       NaN  AHS CAP SPR        1
# 4                       NaN  AHS CAP SPR        1
#
#                            coursetitle                      sectiontitle  \
# 0  AHS CapstoneSpring Pre-registration
# 1  AHS CapstoneSpring Pre-registration
# 2  AHS CapstoneSpring Pre-registration
# 3  AHS CapstoneSpring Pre-registration
# 4  AHS CapstoneSpring Pre-registration
#
#                           professor  \
# 0  Lynch, Caitrin
# 1  Martello, Robert
# 2  Martello, Robert
# 3  Martello, Robert
# 4  Martello, Robert
#
#                                  course-sectiontitle          code-semester
# 0  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0708FA
# 1  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 2  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 3  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 4  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA

# %%
import string

course_names = data['course-sectiontitle'].unique()
course_names = [string.strip(course_name) for course_name in course_names]
df = pd.DataFrame(columns=course_names)
df.head()
# Out:
# Empty DataFrame
# Columns: [AHS CapstoneSpring Pre-registration, History and Society Bodies in Motion: Migration..., Arts and Humanities, Arts and Humanities The Quest, Arts, Humanities, Social ScienceFoundation with Rhetoric "Double Wide" AHS, History of TechnologyFoundation: Technology, Societyand the Environment, Responsive Drawing and VisualThinking, Technology in American History, The Wired Ensemble -Instruments, Voices, Players, Seeing and Hearing:Communicating w/ PhotographsVideo and Sound, Heroes for the RenaissanceEngineer: Leonardo, Nabokov,Bach and Borodin, What is I?, The Stuff of History: Ancient,Revolutionary & ContemporaryMaterials Technologies, The Olin ConductorlessOrchestra, History of Technology:Environment, Culture andGovernment, History of Technology:A Cultural & Contextual Approach, History and Society Migration in the 20th C US, History and Society, Arts and Humanities Self-Explored in Art and Philosp, The Wired Ensemble -Instruments,Voices, Players, Seeing and Hearing:Communicating with Photographs,Video and Sound, The Digital Eye: Photography,Vision, and Visual Communication, Culture & Difference:an Anthropological Approach, The Human Connection: Tools andConcepts from Anthropology forUnderstanding Today's World, What is "I"?, What is 'I'?, Identity from the Mind & theBrain: Who Am I and How Do IKnow, Arts, Humanities, Social ScienceFoundation Topic Art Since 1945: Movmt Theme Cntx, Arts, Humanities, Social ScienceFoundation Topic Creative Writing Workshop, Arts, Humanities, Social ScienceFoundation Topic The Play's the Thing:Shakespeare, Arts, Humanities, Social ScienceFoundation Topic Health and the Urban Environment, Arts, Humanities, Social ScienceFoundation Topic Making Story: Creative Writing, Arts, Humanities, Social ScienceFoundation Topic Live to Write:Creative Writ Wksh, Arts, Humanities, Social ScienceFoundation Topic Islam and the West: Politic/Cult, Arts, Humanities, Social ScienceFoundation Topic Globalzatn: Culture Econ Politic, Arts, Humanities, Social ScienceFoundation Topic Live to Write: Creative Wrt Wksh, Arts, Humanities, Social ScienceFoundation Topic, Arts, Humanities, Social ScienceFoundation Topic Identity from the Mind and Brain, Arts, Humanities, Social ScienceFoundation Topic Human Connection:Undstd Age Hlth, Arts, Humanities, Social ScienceFoundation Topic Art Since 1945:Mov'mt Theme Cnxt, Arts, Humanities, Social ScienceFoundation Topic The Human Connection, Arts, Humanities, Social ScienceFoundation Topic How Supreme Court Shapes Amer, Arts, Humanities, Social ScienceFoundation Topic Media Revolution:Activism & Tech, Arts, Humanities, Social ScienceFoundation Topic Media Revolution: Activism Tech, Arts, Humanities, Social ScienceFoundation Topic Robots Mutants Monsters: Sci Cin, Arts, Humanities, Social ScienceFoundation Topic Robots, Mutants & Monsters: Envi, Babson Cross-Registration, Foundations of Business andEntrepreneurship, The Entrepreneurial Initiative, Products and Markets, Entrepreneurship FoundationTopic Founders Journey with Zolot, Entrepreneurship FoundationTopic Re-imagining Entrepreneurship, The Stuff of History: Materials,Culture in Ancient, Revolutn'aryand Contemporary Times, Six Books that Changed the World, Science Fiction and HistoricalContext, Heroes for the RenaissanceEngineer: Leonardo, Nabokov,Bach, Borodin, The Intersection of Art andScience, Anthropology: Culture,Knowledge & Creativity, Engineering for Humanity, Teaching and Learning inUndergraduate Science andEngineering, Special Topics in Arts,Humanities and Social Science Engr Orch II,Theory Instr Comp, Special Topics in Arts,Humanities and Social Science Social Relations in Cyberspace, Special Topics in Arts,Humanities and Social Science Six Books that Changed the World, Special Topics in Arts,Humanities and Social Science Multicultural Literature, Special Topics in Arts,Humanities and Social Science Life in South Asia, Anthro Intro, Special Topics in Arts,Humanities and Social Science Environmental Enterpris ...
# Index: []
#
# [0 rows x 520 columns]

# %%
grouped = data.groupby('studentid')
for group in grouped:
    student_id = group[0]
    registrations = group[1]
    names = registrations['course-sectiontitle'].unique()
    names = [string.strip(name) for name in names]
    df.loc[student_id] = False
    df.loc[student_id, names] = True
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-584b0ff65761> in <module>()
#       5     names = registrations['course-sectiontitle'].unique()
#       6     df.loc[student_id] = False
# ----> 7     df.loc[student_id, names] = True
#
# /home/isaac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __setitem__(self, key, value)
#     114
#     115     def __setitem__(self, key, value):
# --> 116         indexer = self._get_setitem_indexer(key)
#     117         self._setitem_with_indexer(indexer, value)
#     118
#
# /home/isaac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_setitem_indexer(self, key)
#     104
#     105         if isinstance(key, tuple) and not self.ndim < len(key):
# --> 106             return self._convert_tuple(key, is_setter=True)
#     107         if isinstance(key, range):
#     108             return self._convert_range(key, is_setter=True)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_tuple(self, key, is_setter)
#     155         else:
#     156             for i, k in enumerate(key):
# --> 157                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     158                 keyidx.append(idx)
#     159         return tuple(keyidx)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1148                 mask = check == -1
#    1149                 if mask.any():
# -> 1150                     raise KeyError('%s not in index' % objarr[mask])
#    1151
#    1152                 return _values_from_object(indexer)
#
# KeyError: '[ "The Human Connection: Tools andConcepts from Anthropology forUnderstanding Today\'s World                                 "\n \'Engineering for Humanity                                 \'\n \'Special Topics in Arts,Humanities and Social Science Narrative Psychology            \'\n \'Modeling and Control                                 \'\n \'Real World Measurements                                 \'\n \'Design Nature                                 \'\n \'Principles of Engineering                                 \'\n \'User-Oriented CollaborativeDesign                                 \'\n \'Mechanics of Solids & Structures                                 \'\n \'Dynamics                                 \'\n \'Thermodynamics                                 \'\n \'Software Design                                 \'\n \'Biomechanics                                 \'\n \'Mechanical Design                                 \'\n \'Special Topics in Computing Computational Signal Processing \'\n \'Transport in Biological Systems                                 \'\n \'Modeling and Simulation of thePhysical World                                 \'\n \'Special Topics in Mathematics Linearity 1                     \'\n \'Linearity II                                 \'\n \'Partial Differential Equations                                 \'\n \'Olin Introductory Experience                                 \'\n \'Mechanics Modeling & Simulation Approach  \'\n \'Principles of Modern Biology(with laboratory)                                 \'\n \'Materials Science and SolidState Chemistry(with laboratory) Biomaterials Polymers Mech Prop \'] not in index'

# %%
df.head()
# Out:
#          AHS CapstoneSpring Pre-registration  \
# 10136845                               False
# 10191843                               False
# 10208842                               False
# 10324389                               False
# 10463379                               False
#
#          History and Society Bodies in Motion: Migration...  \
# 10136845                                              False
# 10191843                                              False
# 10208842                                              False
# 10324389                                              False
# 10463379                                               True
#
#          Arts and Humanities Arts and Humanities The Quest  \
# 10136845               False                         False
# 10191843               False                         False
# 10208842               False                         False
# 10324389               False                         False
# 10463379               False                         False
#
#          Arts, Humanities, Social ScienceFoundation with Rhetoric "Double Wide" AHS  \
# 10136845                                              False
# 10191843                                              False
# 10208842                                              False
# 10324389                                              False
# 10463379                                              False
#
#          History of TechnologyFoundation: Technology, Societyand the Environment  \
# 10136845                                              False
# 10191843                                              False
# 10208842                                              False
# 10324389                                              False
# 10463379                                              False
#
#          Responsive Drawing and VisualThinking Technology in American History  \
# 10136845                                 False                          False
# 10191843                                 False                          False
# 10208842                                 False                          False
# 10324389                                 False                          False
# 10463379                                  True                          False
#
#          The Wired Ensemble -Instruments, Voices, Players  \
# 10136845                                            False
# 10191843                                            False
# 10208842                                            False
# 10324389                                            False
# 10463379                                            False
#
#          Seeing and Hearing:Communicating w/ PhotographsVideo and Sound  \
# 10136845                                              False
# 10191843                                              False
# 10208842                                              False
# 10324389                                              False
# 10463379                                              False
#
#                    ...            Seminar: Fundamentals ofMechanical Design  \
# 10136845           ...                                                False
# 10191843           ...                                                False
# 10208842           ...                                                False
# 10324389           ...                                                False
# 10463379           ...                                                False
#
#          Seminar: Intro to Pneumatic andHydraulic Systems  \
# 10136845                                            False
# 10191843                                            False
# 10208842                                            False
# 10324389                                            False
# 10463379                                            False
#
#          Seminar: Musical InstrumentDesign and Engineering  \
# 10136845                                             False
# 10191843                                             False
# 10208842                                             False
# 10324389                                             False
# 10463379                                             False
#
#          Seminar: Introductory PowerSupplies Seminar: Danger! High Voltage!  \
# 10136845                               False                          False
# 10191843                               False                          False
# 10208842                               False                          False
# 10324389                               False                          False
# 10463379                               False                          False
#
#          Seminar: Five More Skills forSoftware Designers  \
# 10136845                                           False
# 10191843                                           False
# 10208842                                           False
# 10324389                                           False
# 10463379                                           False
#
#          Seminar: Data Dashboard Design Seminar: Intro Embedded Software  \
# 10136845                          False                            False
# 10191843                          False                            False
# 10208842                          False                            False
# 10324389                          False                            False
# 10463379                          False                            False
#
#          Introduction to Sustainability Sustainability Synthesis
# 10136845                          False                    False
# 10191843                          False                    False
# 10208842                          False                    False
# 10324389                          False                    False
# 10463379                          False                    False
#
# [5 rows x 520 columns]

# %%
df.to_csv('../data/enrollment.csv')

# %%
df.columns[0]
# Out:
# 'AHS CapstoneSpring Pre-registration'
