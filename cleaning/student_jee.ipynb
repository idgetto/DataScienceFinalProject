# %% [markdown]
# ### Create student csv file in the form

# %% [markdown]
# |id  | sex | entrance_year | grad_class | final_major         | final_major_main | final_major_sub | code_semester           |
# |----|-----|---------------|------------|---------------------|------------------|-----------------|-------------------------|
# |000 | F/M | 2003          | 2007       | Engineering Robotics| Engineering      | Robotics        | ['FND1210 0304FA', ...] |

# %% [markdown]
# |studentid|entranceyear|finalyear|majors|concentrations|finalmajor|finalconcentration|code-semester|
# |--|--|--|--|--|--|--|--|
# |00000000|2002|2006|[Undeclared, Engineering]|[Design]|Engineering|Design|['AHS0000 0203FA', ...]|

# %%
import pandas as pd
data = pd.read_csv('../data/olin0216.csv')

# %%
data.head()
# Out:
#    studentid  semester grade                     major  \
# 0   30876146  0708FA      SR  Engineering
# 1   23925034  0607FA      SR  Engineering
# 2   99052948  0607FA      SR  Electr'l & Computer Engr
# 3   29826367  0607FA      SR  Mechanical Engineering
# 4   91614816  0607FA      SR  Mechanical Engineering
#
#               concentration          code section  \
# 0  Computing                 AHS CAP SPR        1
# 1  Bioengineering            AHS CAP SPR        1
# 2                       NaN  AHS CAP SPR        1
# 3                       NaN  AHS CAP SPR        1
# 4                       NaN  AHS CAP SPR        1
#
#                            coursetitle                      sectiontitle  \
# 0  AHS CapstoneSpring Pre-registration
# 1  AHS CapstoneSpring Pre-registration
# 2  AHS CapstoneSpring Pre-registration
# 3  AHS CapstoneSpring Pre-registration
# 4  AHS CapstoneSpring Pre-registration
#
#                           professor  \
# 0  Lynch, Caitrin
# 1  Martello, Robert
# 2  Martello, Robert
# 3  Martello, Robert
# 4  Martello, Robert
#
#                                  course-sectiontitle          code-semester
# 0  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0708FA
# 1  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 2  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 3  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 4  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34732 entries, 0 to 34731
# Data columns (total 12 columns):
# studentid              34732 non-null int64
# semester               34732 non-null object
# grade                  34732 non-null object
# major                  34732 non-null object
# concentration          13268 non-null object
# code                   34732 non-null object
# section                34732 non-null object
# coursetitle            34732 non-null object
# sectiontitle           32475 non-null object
# professor              32476 non-null object
# course-sectiontitle    34732 non-null object
# code-semester          34732 non-null object
# dtypes: int64(1), object(11)
# memory usage: 3.4+ MB

# %%
def semester_year(semester):
    fs = semester[4:6]
    if fs == 'FA':
        year = semester[:2]
    elif fs == 'SP':
        year = semester[2:4]
    return int(year)

data['term'] = data['semester'].str[4:6]
data['year'] = data['semester'].apply(semester_year)
data.head(1000)
# Out:
#      studentid  semester grade                     major  \
# 0     30876146  0708FA      SR  Engineering
# 1     23925034  0607FA      SR  Engineering
# 2     99052948  0607FA      SR  Electr'l & Computer Engr
# 3     29826367  0607FA      SR  Mechanical Engineering
# 4     91614816  0607FA      SR  Mechanical Engineering
# 5     95699978  0607FA      SR  Electr'l & Computer Engr
# 6     76048649  0607FA      SR  Engineering
# 7     38367538  0607FA      SR  Engineering
# 8     59569488  0607FA      SR  Electr'l & Computer Engr
# 9     82643852  0607FA      SR  Engineering
# 10    86758220  0607FA      SR  Mechanical Engineering
# 11    90300664  0607FA      SR  Mechanical Engineering
# 12    97832629  0607FA      SR  Mechanical Engineering
# 13    98014488  0708FA      SR  Engineering
# 14    26792763  0607FA      SR  Mechanical Engineering
# 15    93596084  0607FA      SR  Electr'l & Computer Engr
# 16    21771652  0607FA      SR  Electr'l & Computer Engr
# 17    64942074  0607FA      SR  Electr'l & Computer Engr
# 18    41759318  0607FA      SR  Electr'l & Computer Engr
# 19    42954567  0607FA      SR  Mechanical Engineering
# 20    44873970  0607FA      SR  Engineering
# 21    38708634  0607FA      SR  Mechanical Engineering
# 22    67373835  0708FA      SR  Electr'l & Computer Engr
# 23    41218183  0607FA      SR  Mechanical Engineering
# 24    69247571  0607FA      SR  Electr'l & Computer Engr
# 25    49433711  0607FA      SR  Mechanical Engineering
# 26    67291012  0708FA      SR  Electr'l & Computer Engr
# 27    84935042  0708FA      SR  Engineering
# 28    40272502  0607FA      SR  Mechanical Engineering
# 29    86902996  0607FA      SR  Engineering
# ..         ...       ...   ...                       ...
# 970   31318503  0910FA      FR  Undeclared
# 971   55752627  0910FA      FR  Undeclared
# 972   57726499  1112FA      FR  Undeclared
# 973   22772364  0910FA      FR  Undeclared
# 974   60892357  0910FA      FR  Undeclared
# 975   32427520  0910FA      FR  Undeclared
# 976   85286664  1011FA      FR  Undeclared
# 977   61778959  0910FA      FR  Undeclared
# 978   73133322  1112FA      FR  Undeclared
# 979   91106070  1112FA      FR  Undeclared
# 980   25788801  1112FA      FR  Undeclared
# 981   28620941  1011FA      FR  Undeclared
# 982   26154461  1011FA      FR  Undeclared
# 983   19262237  1011FA      FR  Undeclared
# 984   60647308  1011FA      FR  Undeclared
# 985   92142820  1112FA      FR  Undeclared
# 986   37838146  1011FA      FR  Undeclared
# 987   16491970  1011FA      FR  Undeclared
# 988   16583689  1011FA      FR  Undeclared
# 989   50146413  1011FA      FR  Undeclared
# 990   29211931  1011FA      FR  Undeclared
# 991   46677611  1011FA      FR  Undeclared
# 992   92968596  1112FA      FR  Undeclared
# 993   37488255  1213FA      FR  Undeclared
# 994   31585105  1112FA      FR  Undeclared
# 995   35882525  1213FA      FR  Undeclared
# 996   28876663  1112FA      FR  Undeclared
# 997   44700438  1213FA      FR  Undeclared
# 998   42868388  1112FA      FR  Undeclared
# 999   22664598  1112FA      FR  Undeclared
#
#                 concentration          code section  \
# 0    Computing                 AHS CAP SPR        1
# 1    Bioengineering            AHS CAP SPR        1
# 2                         NaN  AHS CAP SPR        1
# 3                         NaN  AHS CAP SPR        1
# 4                         NaN  AHS CAP SPR        1
# 5                         NaN  AHS CAP SPR        1
# 6    Systems                   AHS CAP SPR        1
# 7    Computing                 AHS CAP SPR        1
# 8                         NaN  AHS CAP SPR        1
# 9    Materials Science         AHS CAP SPR        1
# 10                        NaN  AHS CAP SPR        1
# 11                        NaN  AHS CAP SPR        1
# 12                        NaN  AHS CAP SPR        1
# 13                        NaN  AHS CAP SPR        1
# 14   Systems                   AHS CAP SPR        1
# 15                        NaN  AHS CAP SPR        1
# 16                        NaN  AHS CAP SPR        1
# 17                        NaN  AHS CAP SPR        1
# 18                        NaN  AHS CAP SPR        1
# 19                        NaN  AHS CAP SPR        1
# 20   Materials Science         AHS CAP SPR        1
# 21                        NaN  AHS CAP SPR        1
# 22                        NaN  AHS CAP SPR        1
# 23                        NaN  AHS CAP SPR        1
# 24                        NaN  AHS CAP SPR        1
# 25                        NaN  AHS CAP SPR        1
# 26                        NaN  AHS CAP SPR        1
# 27   Systems                   AHS CAP SPR        1
# 28                        NaN  AHS CAP SPR        1
# 29   Bioengineering            AHS CAP SPR        1
# ..                        ...           ...     ...
# 970                       NaN  AHSE1122           1
# 971                       NaN  AHSE1122           1
# 972                       NaN  AHSE1122           1
# 973                       NaN  AHSE1122           1
# 974  Computing                 AHSE1122           1
# 975                       NaN  AHSE1122           1
# 976  Bioengineering            AHSE1122           1
# 977  Computing                 AHSE1122           1
# 978  Computing                 AHSE1122           1
# 979  Self Designed             AHSE1122           1
# 980                       NaN  AHSE1122           1
# 981                       NaN  AHSE1122           1
# 982                       NaN  AHSE1122           1
# 983                       NaN  AHSE1122           1
# 984                       NaN  AHSE1122           1
# 985                       NaN  AHSE1122           1
# 986                       NaN  AHSE1122           1
# 987                       NaN  AHSE1122           1
# 988  Bioengineering            AHSE1122           1
# 989                       NaN  AHSE1122           1
# 990                       NaN  AHSE1122           1
# 991                       NaN  AHSE1122           1
# 992                       NaN  AHSE1122           1
# 993                       NaN  AHSE1122           1
# 994  Computing                 AHSE1122           1
# 995  Computing                 AHSE1122           1
# 996                       NaN  AHSE1122           1
# 997                       NaN  AHSE1122           1
# 998                       NaN  AHSE1122           1
# 999  Computing                 AHSE1122           1
#
#                                          coursetitle  \
# 0                AHS CapstoneSpring Pre-registration
# 1                AHS CapstoneSpring Pre-registration
# 2                AHS CapstoneSpring Pre-registration
# 3                AHS CapstoneSpring Pre-registration
# 4                AHS CapstoneSpring Pre-registration
# 5                AHS CapstoneSpring Pre-registration
# 6                AHS CapstoneSpring Pre-registration
# 7                AHS CapstoneSpring Pre-registration
# 8                AHS CapstoneSpring Pre-registration
# 9                AHS CapstoneSpring Pre-registration
# 10               AHS CapstoneSpring Pre-registration
# 11               AHS CapstoneSpring Pre-registration
# 12               AHS CapstoneSpring Pre-registration
# 13               AHS CapstoneSpring Pre-registration
# 14               AHS CapstoneSpring Pre-registration
# 15               AHS CapstoneSpring Pre-registration
# 16               AHS CapstoneSpring Pre-registration
# 17               AHS CapstoneSpring Pre-registration
# 18               AHS CapstoneSpring Pre-registration
# 19               AHS CapstoneSpring Pre-registration
# 20               AHS CapstoneSpring Pre-registration
# 21               AHS CapstoneSpring Pre-registration
# 22               AHS CapstoneSpring Pre-registration
# 23               AHS CapstoneSpring Pre-registration
# 24               AHS CapstoneSpring Pre-registration
# 25               AHS CapstoneSpring Pre-registration
# 26               AHS CapstoneSpring Pre-registration
# 27               AHS CapstoneSpring Pre-registration
# 28               AHS CapstoneSpring Pre-registration
# 29               AHS CapstoneSpring Pre-registration
# ..                                               ...
# 970  The Wired Ensemble -Instruments,Voices, Players
# 971  The Wired Ensemble -Instruments,Voices, Players
# 972  The Wired Ensemble -Instruments,Voices, Players
# 973  The Wired Ensemble -Instruments,Voices, Players
# 974  The Wired Ensemble -Instruments,Voices, Players
# 975  The Wired Ensemble -Instruments,Voices, Players
# 976  The Wired Ensemble -Instruments,Voices, Players
# 977  The Wired Ensemble -Instruments,Voices, Players
# 978  The Wired Ensemble -Instruments,Voices, Players
# 979  The Wired Ensemble -Instruments,Voices, Players
# 980  The Wired Ensemble -Instruments,Voices, Players
# 981  The Wired Ensemble -Instruments,Voices, Players
# 982  The Wired Ensemble -Instruments,Voices, Players
# 983  The Wired Ensemble -Instruments,Voices, Players
# 984  The Wired Ensemble -Instruments,Voices, Players
# 985  The Wired Ensemble -Instruments,Voices, Players
# 986  The Wired Ensemble -Instruments,Voices, Players
# 987  The Wired Ensemble -Instruments,Voices, Players
# 988  The Wired Ensemble -Instruments,Voices, Players
# 989  The Wired Ensemble -Instruments,Voices, Players
# 990  The Wired Ensemble -Instruments,Voices, Players
# 991  The Wired Ensemble -Instruments,Voices, Players
# 992  The Wired Ensemble -Instruments,Voices, Players
# 993  The Wired Ensemble -Instruments,Voices, Players
# 994  The Wired Ensemble -Instruments,Voices, Players
# 995  The Wired Ensemble -Instruments,Voices, Players
# 996  The Wired Ensemble -Instruments,Voices, Players
# 997  The Wired Ensemble -Instruments,Voices, Players
# 998  The Wired Ensemble -Instruments,Voices, Players
# 999  The Wired Ensemble -Instruments,Voices, Players
#
#                          sectiontitle                         professor  \
# 0                                      Lynch, Caitrin
# 1                                      Martello, Robert
# 2                                      Martello, Robert
# 3                                      Martello, Robert
# 4                                      Martello, Robert
# 5                                      Martello, Robert
# 6                                      Martello, Robert
# 7                                      Martello, Robert
# 8                                      Martello, Robert
# 9                                      Martello, Robert
# 10                                     Martello, Robert
# 11                                     Martello, Robert
# 12                                     Martello, Robert
# 13                                     Lynch, Caitrin
# 14                                     Martello, Robert
# 15                                     Martello, Robert
# 16                                     Martello, Robert
# 17                                     Martello, Robert
# 18                                     Martello, Robert
# 19                                     Martello, Robert
# 20                                     Martello, Robert
# 21                                     Martello, Robert
# 22                                     Lynch, Caitrin
# 23                                     Martello, Robert
# 24                                     Martello, Robert
# 25                                     Martello, Robert
# 26                                     Lynch, Caitrin
# 27                                     Lynch, Caitrin
# 28                                     Martello, Robert
# 29                                     Martello, Robert
# ..                                ...                               ...
# 970                                    Dabby, Diana
# 971                                    Dabby, Diana
# 972                                    Dabby, Diana
# 973                                    Dabby, Diana
# 974                                    Dabby, Diana
# 975                                    Dabby, Diana
# 976                                    Dabby, Diana
# 977                                    Dabby, Diana
# 978                                    Dabby, Diana
# 979                                    Dabby, Diana
# 980                                    Dabby, Diana
# 981                                    Dabby, Diana
# 982                                    Dabby, Diana
# 983                                    Dabby, Diana
# 984                                    Dabby, Diana
# 985                                    Dabby, Diana
# 986                                    Dabby, Diana
# 987                                    Dabby, Diana
# 988                                    Dabby, Diana
# 989                                    Dabby, Diana
# 990                                    Dabby, Diana
# 991                                    Dabby, Diana
# 992                                    Dabby, Diana
# 993                                    Dabby, Diana
# 994                                    Dabby, Diana
# 995                                    Dabby, Diana
# 996                                    Dabby, Diana
# 997                                    Dabby, Diana
# 998                                    Dabby, Diana
# 999                                    Dabby, Diana
#
#                                    course-sectiontitle          code-semester  \
# 0    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0708FA
# 1    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 2    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 3    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 4    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 5    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 6    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 7    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 8    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 9    AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 10   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 11   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 12   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 13   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0708FA
# 14   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 15   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 16   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 17   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 18   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 19   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 20   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 21   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 22   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0708FA
# 23   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 24   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 25   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 26   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0708FA
# 27   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0708FA
# 28   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 29   AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# ..                                                 ...                    ...
# 970  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     0910FA
# 971  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     0910FA
# 972  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
# 973  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     0910FA
# 974  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     0910FA
# 975  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     0910FA
# 976  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 977  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     0910FA
# 978  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
# 979  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
# 980  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
# 981  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 982  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 983  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 984  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 985  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
# 986  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 987  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 988  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 989  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 990  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 991  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1011FA
# 992  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
# 993  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1213FA
# 994  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
# 995  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1213FA
# 996  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
# 997  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1213FA
# 998  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
# 999  The Wired Ensemble -Instruments,Voices, Player...  AHSE1122     1112FA
#
#     term  year
# 0     FA     7
# 1     FA     6
# 2     FA     6
# 3     FA     6
# 4     FA     6
# 5     FA     6
# 6     FA     6
# 7     FA     6
# 8     FA     6
# 9     FA     6
# 10    FA     6
# 11    FA     6
# 12    FA     6
# 13    FA     7
# 14    FA     6
# 15    FA     6
# 16    FA     6
# 17    FA     6
# 18    FA     6
# 19    FA     6
# 20    FA     6
# 21    FA     6
# 22    FA     7
# 23    FA     6
# 24    FA     6
# 25    FA     6
# 26    FA     7
# 27    FA     7
# 28    FA     6
# 29    FA     6
# ..   ...   ...
# 970   FA     9
# 971   FA     9
# 972   FA    11
# 973   FA     9
# 974   FA     9
# 975   FA     9
# 976   FA    10
# 977   FA     9
# 978   FA    11
# 979   FA    11
# 980   FA    11
# 981   FA    10
# 982   FA    10
# 983   FA    10
# 984   FA    10
# 985   FA    11
# 986   FA    10
# 987   FA    10
# 988   FA    10
# 989   FA    10
# 990   FA    10
# 991   FA    10
# 992   FA    11
# 993   FA    12
# 994   FA    11
# 995   FA    12
# 996   FA    11
# 997   FA    12
# 998   FA    11
# 999   FA    11
#
# [1000 rows x 14 columns]

# %%
def semester_year(year):
    semyear = 2000 + int(year)
    return semyear

data['semester_year'] = data['year'].apply(semester_year)
data.head()
# Out:
#    studentid  semester grade                     major  \
# 0   30876146  0708FA      SR  Engineering
# 1   23925034  0607FA      SR  Engineering
# 2   99052948  0607FA      SR  Electr'l & Computer Engr
# 3   29826367  0607FA      SR  Mechanical Engineering
# 4   91614816  0607FA      SR  Mechanical Engineering
#
#               concentration          code section  \
# 0  Computing                 AHS CAP SPR        1
# 1  Bioengineering            AHS CAP SPR        1
# 2                       NaN  AHS CAP SPR        1
# 3                       NaN  AHS CAP SPR        1
# 4                       NaN  AHS CAP SPR        1
#
#                            coursetitle                      sectiontitle  \
# 0  AHS CapstoneSpring Pre-registration
# 1  AHS CapstoneSpring Pre-registration
# 2  AHS CapstoneSpring Pre-registration
# 3  AHS CapstoneSpring Pre-registration
# 4  AHS CapstoneSpring Pre-registration
#
#                           professor  \
# 0  Lynch, Caitrin
# 1  Martello, Robert
# 2  Martello, Robert
# 3  Martello, Robert
# 4  Martello, Robert
#
#                                  course-sectiontitle          code-semester  \
# 0  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0708FA
# 1  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 2  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 3  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
# 4  AHS CapstoneSpring Pre-registration           ...  AHS CAP SPR  0607FA
#
#   term  year  semester_year
# 0   FA     7           2007
# 1   FA     6           2006
# 2   FA     6           2006
# 3   FA     6           2006
# 4   FA     6           2006

# %%
studentd = {'id':[],
            'sex':[], 
            'entrance_year':[], 
            'grad_class': [], 
            'final_major': [], 
            'final_major_main': [], 
            'final_major_sub': [], 
            'code-semester':[]}

tag = 0
studenttag = -1
for i in data.index:
    if data['id'][i] not in studentd['id']:
        if tag == i-1:
            studentd['grad_class'].append(data['grad_class'][i-1])
            studentd['final_major'].append(data['major_fullname'][i-1])
            studentd['final_major_main'].append(data['major_main'][i-1])
            studentd['final_major_sub'].append(data['major_sub'][i-1])
        else:
            studentd['id'].append(data['id'][i])
            studentd['sex'].append(data['sex'][i])
            studentd['entrance_year'].append(data['semester_year'][i])
            studentd['code-semester'].append([data['code-semester'][i]])
            studenttag += 1
    else:
        tag = i
        studentd['code-semester'][studenttag].append(data['code-semester'][i])

studentd['grad_class'].append(data['grad_class'][len(data)-1])
studentd['final_major'].append(data['major_fullname'][len(data)-1])
studentd['final_major_main'].append(data['major_main'][len(data)-1])
studentd['final_major_sub'].append(data['major_sub'][len(data)-1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-0565a7ed4ce6> in <module>()
#      11 studenttag = -1
#      12 for i in data.index:
# ---> 13     if data['id'][i] not in studentd['id']:
#      14         if tag == i-1:
#      15             studentd['grad_class'].append(data['grad_class'][i-1])
#
# /home/jkim/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /home/jkim/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /home/jkim/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /home/jkim/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/jkim/anaconda2/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'id'

# %%
studentd = {'studentid':[],
            'entranceyear':[],
            'finalyear':[],
            'majors': [], 
            'concentrations': [], 
            'code-semester':[]}

grouped = data.groupby('studentid')
for group in grouped:
    studentd['studentid'].append(group[0])
    studentd['code-semester'].append(group[1]['code-semester'].unique())
    studentd['majors'].append(group[1]['major'].unique())
    studentd['concentrations'].append(group[1]['concentration'].unique())
    studentd['entranceyear'].append(min(group[1]['semester_year'].unique()))
    studentd['finalyear'].append(max(group[1]['semester_year'].unique()))

# %%
student = pd.DataFrame(studentd)

# %%
def last_element(element):
    return element[-1]

student['finalmajor'] = student['majors'].apply(last_element)
student['finalconcentration'] = student['concentrations'].apply(last_element)

# %%
columns = ['studentid','entranceyear','finalyear','majors','concentrations','finalmajor','finalconcentration','code-semester']
student = student[columns]

student.head()
# Out:
#    studentid  entranceyear  finalyear  \
# 0   10136845          2013       2016
# 1   10191843          2014       2015
# 2   10208842          2014       2016
# 3   10324389          2007       2011
# 4   10463379          2003       2007
#
#                                               majors  \
# 0  [Undeclared              , Mechanical Engineer...
# 1                         [Undeclared              ]
# 2  [Undeclared              , Engineering        ...
# 3  [Undeclared              , Engineering        ...
# 4  [Undeclared              , Electr'l & Computer...
#
#                concentrations                finalmajor  \
# 0                       [nan]  Mechanical Engineering
# 1                       [nan]  Undeclared
# 2  [Computing               ]  Engineering
# 3  [Self Designed           ]  Engineering
# 4                       [nan]  Mechanical Engineering
#
#          finalconcentration                                      code-semester
# 0                       NaN  [AHSE1145     1314FA  , AHSE2141     1314SP  ,...
# 1                       NaN  [AHSE1145     1415FA  , AHSE1515     1415SP  ,...
# 2  Computing                 [AHSE1199     1415FA  , AHSE1515     1415SP  ,...
# 3  Self Designed             [AHSE1199     0708FA  , AHSE1500     0809FA  ,...
# 4                       NaN  [AHS1101      0304FA  , AHS1111      0304SP  ,...

# %%
import numpy as np
for i in student.index:
    if student.finalmajor[i][0:11] == 'Engineering':
        pass
    else:
        student.finalconcentration[i] = np.nan
# Out:
# /home/jkim/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
student.to_csv('../data/student0216.csv', index = False)
