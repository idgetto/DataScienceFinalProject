# %% [markdown]
# ### Create student csv file in the form

# %% [markdown]
# |id  | sex | entrance_year | grad_class | final_major         | final_major_main | final_major_sub | code_semester           |
# |----|-----|---------------|------------|---------------------|------------------|-----------------|-------------------------|
# |000 | F/M | 2003          | 2007       | Engineering Robotics| Engineering      | Robotics        | ['FND1210 0304FA', ...] |

# %% [markdown]
# |studentid|entranceyear|finalyear|majors|concentrations|finalmajor|finalconcentration|code-semester|
# |--|--|--|--|--|--|--|--|
# |00000000|2002|2006|[Undeclared, Engineering]|[Design]|Engineering|Design|['AHS0000 0203FA', ...]|

# %%
import pandas as pd
data = pd.read_csv('../data/registrations1.csv')

# %%
data.head()
# Out:
#    studentid semester grade                     major   concentration  \
# 0   30876146   0708FA    SR               Engineering       Computing
# 1   23925034   0607FA    SR               Engineering  Bioengineering
# 2   99052948   0607FA    SR  Electr'l & Computer Engr             NaN
# 3   29826367   0607FA    SR    Mechanical Engineering             NaN
# 4   91614816   0607FA    SR    Mechanical Engineering             NaN
#
#           code section                          coursetitle sectiontitle  \
# 0  AHS CAP SPR       1  AHS CapstoneSpring Pre-registration          NaN
# 1  AHS CAP SPR       1  AHS CapstoneSpring Pre-registration          NaN
# 2  AHS CAP SPR       1  AHS CapstoneSpring Pre-registration          NaN
# 3  AHS CAP SPR       1  AHS CapstoneSpring Pre-registration          NaN
# 4  AHS CAP SPR       1  AHS CapstoneSpring Pre-registration          NaN
#
#           professor                  course-sectiontitle        code-semester  \
# 0    Lynch, Caitrin  AHS CapstoneSpring Pre-registration  AHS CAP SPR  0708FA
# 1  Martello, Robert  AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 2  Martello, Robert  AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 3  Martello, Robert  AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 4  Martello, Robert  AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
#
#    Unnamed: 0 coursetype
# 0         247        NaN
# 1         247        NaN
# 2         247        NaN
# 3         247        NaN
# 4         247        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34732 entries, 0 to 34731
# Data columns (total 14 columns):
# studentid              34732 non-null int64
# semester               34732 non-null object
# grade                  34732 non-null object
# major                  34732 non-null object
# concentration          13268 non-null object
# code                   34732 non-null object
# section                34732 non-null object
# coursetitle            34732 non-null object
# sectiontitle           4930 non-null object
# professor              32476 non-null object
# course-sectiontitle    34732 non-null object
# code-semester          34732 non-null object
# Unnamed: 0             34732 non-null int64
# coursetype             15902 non-null object
# dtypes: int64(2), object(12)
# memory usage: 4.0+ MB

# %%
def semester_year(semester):
    fs = semester[4:6]
    if fs == 'FA':
        year = semester[:2]
    elif fs == 'SP':
        year = semester[2:4]
    return int(year)

data['term'] = data['semester'].str[4:6]
data['year'] = data['semester'].apply(semester_year)
data.head(1000)
# Out:
#      studentid semester grade                     major      concentration  \
# 0     30876146   0708FA    SR               Engineering          Computing
# 1     23925034   0607FA    SR               Engineering     Bioengineering
# 2     99052948   0607FA    SR  Electr'l & Computer Engr                NaN
# 3     29826367   0607FA    SR    Mechanical Engineering                NaN
# 4     91614816   0607FA    SR    Mechanical Engineering                NaN
# 5     95699978   0607FA    SR  Electr'l & Computer Engr                NaN
# 6     76048649   0607FA    SR               Engineering            Systems
# 7     38367538   0607FA    SR               Engineering          Computing
# 8     59569488   0607FA    SR  Electr'l & Computer Engr                NaN
# 9     82643852   0607FA    SR               Engineering  Materials Science
# 10    86758220   0607FA    SR    Mechanical Engineering                NaN
# 11    90300664   0607FA    SR    Mechanical Engineering                NaN
# 12    97832629   0607FA    SR    Mechanical Engineering                NaN
# 13    98014488   0708FA    SR               Engineering                NaN
# 14    26792763   0607FA    SR    Mechanical Engineering            Systems
# 15    93596084   0607FA    SR  Electr'l & Computer Engr                NaN
# 16    21771652   0607FA    SR  Electr'l & Computer Engr                NaN
# 17    64942074   0607FA    SR  Electr'l & Computer Engr                NaN
# 18    41759318   0607FA    SR  Electr'l & Computer Engr                NaN
# 19    42954567   0607FA    SR    Mechanical Engineering                NaN
# 20    44873970   0607FA    SR               Engineering  Materials Science
# 21    38708634   0607FA    SR    Mechanical Engineering                NaN
# 22    67373835   0708FA    SR  Electr'l & Computer Engr                NaN
# 23    41218183   0607FA    SR    Mechanical Engineering                NaN
# 24    69247571   0607FA    SR  Electr'l & Computer Engr                NaN
# 25    49433711   0607FA    SR    Mechanical Engineering                NaN
# 26    67291012   0708FA    SR  Electr'l & Computer Engr                NaN
# 27    84935042   0708FA    SR               Engineering            Systems
# 28    40272502   0607FA    SR    Mechanical Engineering                NaN
# 29    86902996   0607FA    SR               Engineering     Bioengineering
# ..         ...      ...   ...                       ...                ...
# 970   31318503   0910FA    FR                Undeclared                NaN
# 971   55752627   0910FA    FR                Undeclared                NaN
# 972   57726499   1112FA    FR                Undeclared                NaN
# 973   22772364   0910FA    FR                Undeclared                NaN
# 974   60892357   0910FA    FR                Undeclared          Computing
# 975   32427520   0910FA    FR                Undeclared                NaN
# 976   85286664   1011FA    FR                Undeclared     Bioengineering
# 977   61778959   0910FA    FR                Undeclared          Computing
# 978   73133322   1112FA    FR                Undeclared          Computing
# 979   91106070   1112FA    FR                Undeclared      Self Designed
# 980   25788801   1112FA    FR                Undeclared                NaN
# 981   28620941   1011FA    FR                Undeclared                NaN
# 982   26154461   1011FA    FR                Undeclared                NaN
# 983   19262237   1011FA    FR                Undeclared                NaN
# 984   60647308   1011FA    FR                Undeclared                NaN
# 985   92142820   1112FA    FR                Undeclared                NaN
# 986   37838146   1011FA    FR                Undeclared                NaN
# 987   16491970   1011FA    FR                Undeclared                NaN
# 988   16583689   1011FA    FR                Undeclared     Bioengineering
# 989   50146413   1011FA    FR                Undeclared                NaN
# 990   29211931   1011FA    FR                Undeclared                NaN
# 991   46677611   1011FA    FR                Undeclared                NaN
# 992   92968596   1112FA    FR                Undeclared                NaN
# 993   37488255   1213FA    FR                Undeclared                NaN
# 994   31585105   1112FA    FR                Undeclared          Computing
# 995   35882525   1213FA    FR                Undeclared          Computing
# 996   28876663   1112FA    FR                Undeclared                NaN
# 997   44700438   1213FA    FR                Undeclared                NaN
# 998   42868388   1112FA    FR                Undeclared                NaN
# 999   22664598   1112FA    FR                Undeclared          Computing
#
#             code section                                      coursetitle  \
# 0    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 1    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 2    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 3    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 4    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 5    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 6    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 7    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 8    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 9    AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 10   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 11   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 12   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 13   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 14   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 15   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 16   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 17   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 18   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 19   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 20   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 21   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 22   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 23   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 24   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 25   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 26   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 27   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 28   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# 29   AHS CAP SPR       1              AHS CapstoneSpring Pre-registration
# ..           ...     ...                                              ...
# 970     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 971     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 972     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 973     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 974     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 975     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 976     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 977     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 978     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 979     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 980     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 981     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 982     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 983     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 984     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 985     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 986     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 987     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 988     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 989     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 990     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 991     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 992     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 993     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 994     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 995     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 996     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 997     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 998     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
# 999     AHSE1122       1  The Wired Ensemble -Instruments,Voices, Players
#
#     sectiontitle         professor  \
# 0            NaN    Lynch, Caitrin
# 1            NaN  Martello, Robert
# 2            NaN  Martello, Robert
# 3            NaN  Martello, Robert
# 4            NaN  Martello, Robert
# 5            NaN  Martello, Robert
# 6            NaN  Martello, Robert
# 7            NaN  Martello, Robert
# 8            NaN  Martello, Robert
# 9            NaN  Martello, Robert
# 10           NaN  Martello, Robert
# 11           NaN  Martello, Robert
# 12           NaN  Martello, Robert
# 13           NaN    Lynch, Caitrin
# 14           NaN  Martello, Robert
# 15           NaN  Martello, Robert
# 16           NaN  Martello, Robert
# 17           NaN  Martello, Robert
# 18           NaN  Martello, Robert
# 19           NaN  Martello, Robert
# 20           NaN  Martello, Robert
# 21           NaN  Martello, Robert
# 22           NaN    Lynch, Caitrin
# 23           NaN  Martello, Robert
# 24           NaN  Martello, Robert
# 25           NaN  Martello, Robert
# 26           NaN    Lynch, Caitrin
# 27           NaN    Lynch, Caitrin
# 28           NaN  Martello, Robert
# 29           NaN  Martello, Robert
# ..           ...               ...
# 970          NaN      Dabby, Diana
# 971          NaN      Dabby, Diana
# 972          NaN      Dabby, Diana
# 973          NaN      Dabby, Diana
# 974          NaN      Dabby, Diana
# 975          NaN      Dabby, Diana
# 976          NaN      Dabby, Diana
# 977          NaN      Dabby, Diana
# 978          NaN      Dabby, Diana
# 979          NaN      Dabby, Diana
# 980          NaN      Dabby, Diana
# 981          NaN      Dabby, Diana
# 982          NaN      Dabby, Diana
# 983          NaN      Dabby, Diana
# 984          NaN      Dabby, Diana
# 985          NaN      Dabby, Diana
# 986          NaN      Dabby, Diana
# 987          NaN      Dabby, Diana
# 988          NaN      Dabby, Diana
# 989          NaN      Dabby, Diana
# 990          NaN      Dabby, Diana
# 991          NaN      Dabby, Diana
# 992          NaN      Dabby, Diana
# 993          NaN      Dabby, Diana
# 994          NaN      Dabby, Diana
# 995          NaN      Dabby, Diana
# 996          NaN      Dabby, Diana
# 997          NaN      Dabby, Diana
# 998          NaN      Dabby, Diana
# 999          NaN      Dabby, Diana
#
#                                  course-sectiontitle        code-semester  \
# 0                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0708FA
# 1                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 2                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 3                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 4                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 5                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 6                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 7                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 8                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 9                AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 10               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 11               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 12               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 13               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0708FA
# 14               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 15               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 16               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 17               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 18               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 19               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 20               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 21               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 22               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0708FA
# 23               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 24               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 25               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 26               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0708FA
# 27               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0708FA
# 28               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# 29               AHS CapstoneSpring Pre-registration  AHS CAP SPR  0607FA
# ..                                               ...                  ...
# 970  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     0910FA
# 971  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     0910FA
# 972  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
# 973  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     0910FA
# 974  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     0910FA
# 975  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     0910FA
# 976  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 977  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     0910FA
# 978  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
# 979  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
# 980  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
# 981  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 982  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 983  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 984  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 985  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
# 986  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 987  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 988  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 989  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 990  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 991  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1011FA
# 992  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
# 993  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1213FA
# 994  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
# 995  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1213FA
# 996  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
# 997  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1213FA
# 998  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
# 999  The Wired Ensemble -Instruments,Voices, Players  AHSE1122     1112FA
#
#      Unnamed: 0 coursetype term  year
# 0           247        NaN   FA     7
# 1           247        NaN   FA     6
# 2           247        NaN   FA     6
# 3           247        NaN   FA     6
# 4           247        NaN   FA     6
# 5           247        NaN   FA     6
# 6           247        NaN   FA     6
# 7           247        NaN   FA     6
# 8           247        NaN   FA     6
# 9           247        NaN   FA     6
# 10          247        NaN   FA     6
# 11          247        NaN   FA     6
# 12          247        NaN   FA     6
# 13          247        NaN   FA     7
# 14          247        NaN   FA     6
# 15          247        NaN   FA     6
# 16          247        NaN   FA     6
# 17          247        NaN   FA     6
# 18          247        NaN   FA     6
# 19          247        NaN   FA     6
# 20          247        NaN   FA     6
# 21          247        NaN   FA     6
# 22          247        NaN   FA     7
# 23          247        NaN   FA     6
# 24          247        NaN   FA     6
# 25          247        NaN   FA     6
# 26          247        NaN   FA     7
# 27          247        NaN   FA     7
# 28          247        NaN   FA     6
# 29          247        NaN   FA     6
# ..          ...        ...  ...   ...
# 970         253        NaN   FA     9
# 971         253        NaN   FA     9
# 972         253        NaN   FA    11
# 973         253        NaN   FA     9
# 974         253        NaN   FA     9
# 975         253        NaN   FA     9
# 976         253        NaN   FA    10
# 977         253        NaN   FA     9
# 978         253        NaN   FA    11
# 979         253        NaN   FA    11
# 980         253        NaN   FA    11
# 981         253        NaN   FA    10
# 982         253        NaN   FA    10
# 983         253        NaN   FA    10
# 984         253        NaN   FA    10
# 985         253        NaN   FA    11
# 986         253        NaN   FA    10
# 987         253        NaN   FA    10
# 988         253        NaN   FA    10
# 989         253        NaN   FA    10
# 990         253        NaN   FA    10
# 991         253        NaN   FA    10
# 992         253        NaN   FA    11
# 993         253        NaN   FA    12
# 994         253        NaN   FA    11
# 995         253        NaN   FA    12
# 996         253        NaN   FA    11
# 997         253        NaN   FA    12
# 998         253        NaN   FA    11
# 999         253        NaN   FA    11
#
# [1000 rows x 16 columns]

# %%
data.coursetype.unique()
# Out:
# array([nan, 'design', 'ece', 'cs', 'me', 'general', 'bio', 'ms'], dtype=object)

# %%
def semester_year(year):
    semyear = 2000 + int(year)
    return semyear

def me(coursetype):
    if coursetype == 'me':
        return 1
    else:
        return 0

def ece(coursetype):
    if coursetype == 'ece':
        return 1
    else:
        return 0
    
def cs(coursetype):
    if coursetype == 'cs':
        return 1
    else:
        return 0
    
def design(coursetype):
    if coursetype == 'design':
        return 1
    else:
        return 0

def bio(coursetype):
    if coursetype == 'bio':
        return 1
    else:
        return 0

data['semester_year'] = data['year'].apply(semester_year)
data['me'] = data['coursetype'].apply(me)
data['ece'] = data['coursetype'].apply(ece)
data['cs'] = data['coursetype'].apply(cs)
data['design'] = data['coursetype'].apply(design)
data['bio'] = data['coursetype'].apply(bio)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34732 entries, 0 to 34731
# Data columns (total 22 columns):
# studentid              34732 non-null int64
# semester               34732 non-null object
# grade                  34732 non-null object
# major                  34732 non-null object
# concentration          13268 non-null object
# code                   34732 non-null object
# section                34732 non-null object
# coursetitle            34732 non-null object
# sectiontitle           4930 non-null object
# professor              32476 non-null object
# course-sectiontitle    34732 non-null object
# code-semester          34732 non-null object
# Unnamed: 0             34732 non-null int64
# coursetype             15902 non-null object
# term                   34732 non-null object
# year                   34732 non-null int64
# semester_year          34732 non-null int64
# me                     34732 non-null int64
# ece                    34732 non-null int64
# cs                     34732 non-null int64
# design                 34732 non-null int64
# bio                    34732 non-null int64
# dtypes: int64(9), object(13)
# memory usage: 6.1+ MB

# %%
# studentd = {'id':[],
#             'sex':[], 
#             'entrance_year':[], 
#             'grad_class': [], 
#             'final_major': [], 
#             'final_major_main': [], 
#             'final_major_sub': [], 
#             'code-semester':[]}

# tag = 0
# studenttag = -1
# for i in data.index:
#     if data['id'][i] not in studentd['id']:
#         if tag == i-1:
#             studentd['grad_class'].append(data['grad_class'][i-1])
#             studentd['final_major'].append(data['major_fullname'][i-1])
#             studentd['final_major_main'].append(data['major_main'][i-1])
#             studentd['final_major_sub'].append(data['major_sub'][i-1])
#         else:
#             studentd['id'].append(data['id'][i])
#             studentd['sex'].append(data['sex'][i])
#             studentd['entrance_year'].append(data['semester_year'][i])
#             studentd['code-semester'].append([data['code-semester'][i]])
#             studenttag += 1
#     else:
#         tag = i
#         studentd['code-semester'][studenttag].append(data['code-semester'][i])

# studentd['grad_class'].append(data['grad_class'][len(data)-1])
# studentd['final_major'].append(data['major_fullname'][len(data)-1])
# studentd['final_major_main'].append(data['major_main'][len(data)-1])
# studentd['final_major_sub'].append(data['major_sub'][len(data)-1])

# %%
studentd = {'studentid':[],
            'entranceyear':[],
            'finalyear':[],
            'majors': [], 
            'concentrations': [], 
            'code-semester':[], 
            'me':[],'ece':[],'cs':[],'design':[],'bio':[]}

grouped = data.groupby('studentid')
for group in grouped:
    studentd['studentid'].append(group[0])
    studentd['code-semester'].append(group[1]['code-semester'].unique())
    studentd['majors'].append(group[1]['major'].unique())
    studentd['concentrations'].append(group[1]['concentration'].unique())
    studentd['entranceyear'].append(min(group[1]['semester_year'].unique()))
    studentd['finalyear'].append(max(group[1]['semester_year'].unique()))
    studentd['me'].append(group[1]['me'].sum())
    studentd['ece'].append(group[1]['ece'].sum())
    studentd['cs'].append(group[1]['cs'].sum())
    studentd['design'].append(group[1]['design'].sum())
    studentd['bio'].append(group[1]['bio'].sum())

# 75                [nan]   1       3    6          2010       2014
# 76                [nan]   2       3    7          2002       2006
# 77      [Self Designed]   2       3    5          2011       2015
# 78                [nan]   0       4    1          2014       2016
# 79      [Self Designed]   1       2    3          2007       2010
# 80                [nan]   0       5    5          2011       2015
# 81                [nan]   0       4    1          2010       2014
# 82                [nan]   1       4    3          2002       2006
# 83     [Bioengineering]   1       3    2          2010       2014
# 84                [nan]   1       3    6          2013       2016
# 85                [nan]   0       3    1          2014       2016
# 86                [nan]   0       4    1          2014       2016
# 87           [Robotics]   1       3    1          2010       2014
# 88                [nan]   2       2    1          2015       2016
# 89                [nan]   1       2    1          2015       2016
# 90      [Self Designed]   1       4    3          2009       2013
# 91                [nan]   1       3    9          2007       2011
# 92          [Computing]   4       3    4          2010       2014
# 93                [nan]   1       2    1          2013       2015
# 94                [nan]   1       6    2          2005       2010
# 95                [nan]   4       3   10          2006       2010
# 96          [Computing]   5       3    4          2006       2010
# 97                [nan]   1       2    1          2015       2016
# 98                [nan]   0       3    3          2007       2011
# 99          [Computing]   5       4    1          2012       2016
#
#                                                majors  me  studentid
# 0                [Undeclared, Mechanical Engineering]   6   10136845
# 1                                        [Undeclared]   3   10191843
# 2                           [Undeclared, Engineering]   0   10208842
# 3                           [Undeclared, Engineering]   2   10324389
# 4   [Undeclared, Electr'l & Computer Engr, Mechani...   7   10463379
# 5                [Undeclared, Mechanical Engineering]   9   10478316
# 6                           [Undeclared, Engineering]   1   10510869
# 7                [Undeclared, Mechanical Engineering]   6   10543230
# 8                           [Undeclared, Engineering]   1   10585887
# 9                           [Undeclared, Engineering]   0   10784794
# 10             [Undeclared, Electr'l & Computer Engr]   0   10929710
# 11               [Undeclared, Mechanical Engineering]   7   10950557
# 12                                       [Undeclared]   1   11009801
# 13                          [Undeclared, Engineering]   3   11303124
# 14  [Undeclared, Mechanical Engineering, Engineering]   2   11596277
# 15               [Undeclared, Mechanical Engineering]   4   11598375
# 16                          [Undeclared, Engineering]   1   11769609
# 17               [Undeclared, Mechanical Engineering]   7   11826487
# 18               [Undeclared, Mechanical Engineering]   8   11835906
# 19                                       [Undeclared]   1   11855937
# 20             [Undeclared, Electr'l & Computer Engr]   2   11917523
# 21                          [Undeclared, Engineering]   1   12018722
# 22             [Undeclared, Electr'l & Computer Engr]   2   12033288
# 23             [Undeclared, Electr'l & Computer Engr]   2   12065023
# 24               [Undeclared, Mechanical Engineering]   7   12082001
# 25             [Undeclared, Electr'l & Computer Engr]   2   12112622
# 26             [Undeclared, Electr'l & Computer Engr]   0   12280467
# 27             [Undeclared, Electr'l & Computer Engr]   2   12312728
# 28                                       [Undeclared]   0   12419204
# 29                          [Undeclared, Engineering]   1   12454265
# ..                                                ...  ..        ...
# 70             [Undeclared, Electr'l & Computer Engr]   1   15642056
# 71                          [Undeclared, Engineering]   2   15654651
# 72                          [Undeclared, Engineering]   1   15715668
# 73                                       [Undeclared]   1   15784727
# 74                          [Undeclared, Engineering]   3   15913733
# 75               [Undeclared, Mechanical Engineering]   9   15980918
# 76             [Undeclared, Electr'l & Computer Engr]   1   16062888
# 77                          [Undeclared, Engineering]   5   16086298
# 78                                       [Undeclared]   3   16213079
# 79                          [Undeclared, Engineering]   2   16298834
# 80               [Undeclared, Mechanical Engineering]   8   16325538
# 81               [Undeclared, Mechanical Engineering]   9   16491970
# 82  [Undeclared, Engineering, Mechanical Engineering]   7   16495441
# 83                          [Undeclared, Engineering]   2   16583689
# 84             [Undeclared, Electr'l & Computer Engr]   0   16587772
# 85               [Undeclared, Mechanical Engineering]   3   16735176
# 86                                       [Undeclared]   2   16764646
# 87  [Undeclared, Mechanical Engineering, Engineering]   7   16993165
# 88                                       [Undeclared]   0   17020196
# 89                                       [Undeclared]   0   17038688
# 90                          [Undeclared, Engineering]   1   17106020
# 91             [Undeclared, Electr'l & Computer Engr]   1   17126859
# 92             [Undeclared, Electr'l & Computer Engr]   1   17263001
# 93               [Undeclared, Mechanical Engineering]   8   17272848
# 94  [Undeclared, Mechanical Engineering, Engineering]   6   17274948
# 95             [Undeclared, Electr'l & Computer Engr]   1   17278590
# 96                          [Undeclared, Engineering]   1   17299788
# 97                                       [Undeclared]   0   17346561
# 98               [Undeclared, Mechanical Engineering]   8   17391655
# 99                          [Undeclared, Engineering]   1   17462627
#
# [100 rows x 11 columns]

# %%
def last_element(element):
    return element[-1]

student['finalmajor'] = student['majors'].apply(last_element)
student['finalconcentration'] = student['concentrations'].apply(last_element)

# %%
columns = ['studentid','entranceyear','finalyear',
           'majors','concentrations','finalmajor','finalconcentration',
           'code-semester','me','ece','design','cs','bio']
student = student[columns]

student.head()
# Out:
#    studentid  entranceyear  finalyear  \
# 0   10136845          2013       2016
# 1   10191843          2014       2015
# 2   10208842          2014       2016
# 3   10324389          2007       2011
# 4   10463379          2003       2007
#
#                                               majors   concentrations  \
# 0               [Undeclared, Mechanical Engineering]            [nan]
# 1                                       [Undeclared]            [nan]
# 2                          [Undeclared, Engineering]      [Computing]
# 3                          [Undeclared, Engineering]  [Self Designed]
# 4  [Undeclared, Electr'l & Computer Engr, Mechani...            [nan]
#
#                finalmajor finalconcentration  \
# 0  Mechanical Engineering                NaN
# 1              Undeclared                NaN
# 2             Engineering          Computing
# 3             Engineering      Self Designed
# 4  Mechanical Engineering                NaN
#
#                                        code-semester  me  ece  design  cs  bio
# 0  [AHSE1145     1314FA, AHSE2141     1314SP, AHS...   6    1       4   3    1
# 1  [AHSE1145     1415FA, AHSE1515     1415SP, ENG...   3    1       2   1    0
# 2  [AHSE1199     1415FA, AHSE1515     1415SP, ENG...   0    2       2   3    0
# 3  [AHSE1199     0708FA, AHSE1500     0809FA, AHS...   2    2       6   1    3
# 4  [AHS1101      0304FA, AHS1111      0304SP, AHS...   7    2       3   1    0

# %%
import numpy as np
for i in student.index:
    if student.finalmajor[i][0:11] == 'Engineering':
        pass
    else:
        student.finalconcentration[i] = np.nan
# Out:
# /home/jkim/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
student.to_csv('../data/student0216.csv', index = False)
